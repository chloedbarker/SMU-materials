# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import torch
import tensorflow as tf

# %%
python3 -m pip install numpy pandas scipy scikit-learn torch tensorflow
# Out:
#   Cell In[17], line 1
#     python3 -m pip install numpy pandas scipy scikit-learn torch tensorflow
#                ^
# SyntaxError: invalid syntax

# %%
print(list(range(0,5)))
# Out:
# [0, 1, 2, 3, 4]

# %%
for i in range (5):
    print (i)
    print (i*i)
    if i == 4:
        print ("Hi")
# Out:
# 0
# 0
# 1
# 1
# 2
# 4
# 3
# 9
# 4
# 16
# Hi

# %%
# By label
data.loc[0:3,["column1","column2"]]

# %%
# By location
data.iloc[0:3,0:2]
